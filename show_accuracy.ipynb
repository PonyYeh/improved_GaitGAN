# %% [markdown]
# # plot accuracy of 11 probe angles (11 pictures)

# %%
import pandas as pd 
from matplotlib import pyplot as plt
# #NM
# baseline_path = './Transform_Model/Model_64x64_baselineKNN/PerAngle_knn_ProbeNM_BaselineKNN_1.csv'
# path_proposed = './Transform_Model/Model_64x64_TripletSAGAN_90_trial3/PerAngle_embedding_knn_ProbeNM_600.csv'
# gaitganTL_path = './Transform_Model/Model_64x64_TripletGAN_90_trial10/PerAngle_generatedata_knn_ProbeNM_6191.csv' 
# paper_path = './Transform_Model/Model_64x64_GaitGAN_90/PerAngle_generatedata_knn_ProbeNM_600.csv'

# #BG
# baseline_path = './Transform_Model/Model_64x64_baselineKNN/PerAngle_knn_ProbeBG_BaselineKNN.csv'
# path_proposed = './Transform_Model/Model_64x64_TripletSAGAN_90_trial3/PerAngle_embedding_knn_ProbeBG_600.csv'
# gaitganTL_path = './Transform_Model/Model_64x64_TripletGAN_90_trial10/PerAngle_generatedata_knn_ProbeBG_6191.csv' 
# paper_path = './Transform_Model/Model_64x64_GaitGAN_90/PerAngle_embedding_knn_ProbeBG_6001.csv'

#CL
baseline_path = './Transform_Model/Model_64x64_baselineKNN/PerAngle_knn_ProbeCL_BaselineKNN.csv'
path_proposed = './Transform_Model/Model_64x64_TripletSAGAN_90_trial3/PerAngle_embedding_knn_ProbeCL_600.csv'
gaitganTL_path = './Transform_Model/Model_64x64_TripletGAN_90_trial10/PerAngle_generatedata_knn_ProbeCL_6191.csv' 
paper_path = './Transform_Model/Model_64x64_GaitGAN_90/PerAngle_embedding_knn_ProbeCL_6001.csv'

for angle in range(11):
    angle_ = angle*18
    df_bs = pd.read_csv(baseline_path, sep=',',header=None)
    df_proposed = pd.read_csv(path_proposed, sep=',',header=None)
    df_gaitganTL = pd.read_csv(gaitganTL_path, sep=',',header=None)
    df_paper = pd.read_csv(paper_path, sep=',',header=None)
    del df_proposed[angle]
    del df_bs[angle]
    del df_gaitganTL[angle]
    del df_paper[angle]

    #2
    l = [i for i in range(11) if i != angle]

    # arr = np.array(total_probe_muAcc)
    fig1 = plt.figure(1,figsize=(8, 6))                                           # 创建一个Figure                                                          
    ax1 = fig1.add_subplot(1,1,1)                                  # add_subplot()创建一个子图或多个子图                                            
    ax1.plot((df_bs.iloc[angle][:10])*100, 'o-', color = 'black', label = 'GEI')       # label设置标签,'o-'代表线型                                                           
    ax1.plot((df_paper.iloc[angle][:10])*100, '>-', color = 'red', label = 'GaitGAN') 
    ax1.plot((df_gaitganTL.iloc[angle][:10])*100, '*-', color = 'blue', label = 'GaitGAN+TL') 
    ax1.plot((df_proposed.iloc[angle][:10])*100, '*-', color = 'green', label = 'Proposed') 
    ax1.set_xlabel('Gallery Angle',fontsize = 15)                              # 设置x轴的标签, fontsize设置字体大小                                             
    ax1.set_ylabel('Accuracy (%)', fontsize = 15)  
    # ax1.set_ylim([0,100])
    ax1.set_xticks(l) 
    ax1.set_xticklabels((df_bs.columns[:-1])*18)
    ax1.set_yticks(range(0,101,10)) 
    ax1.set_title('Probe CL angle at $'+str(angle_)+'^\circ$', fontsize = 18)
    ax1.grid(True, which='major', axis='y')                      # 设置网格                                                               
    ax1.legend(loc = 1, numpoints = 1)    
    plt.savefig('./Milestone/probecl_crossview/crossview'+str(angle_)+'_total.png')# 图例, loc='best',即图例放在最不碍事的位置,numpoint图例上自由一个点                       
    plt.show()
    plt.close()

# %% [markdown]
# # plot accuracy of 54, 126 probe angles (1X2 pics)

# %%
import pandas as pd 
from matplotlib import pyplot as plt
# NM
# baseline_path = './Transform_Model/Model_64x64_baselineKNN/PerAngle_knn_ProbeNM_BaselineKNN_1.csv'
# path_proposed = './Transform_Model/Model_64x64_TripletSAGAN_90_trial3/PerAngle_embedding_knn_ProbeNM_600.csv'
# gaitganTL_path = './Transform_Model/Model_64x64_TripletGAN_90_trial10/PerAngle_generatedata_knn_ProbeNM_6191.csv' 
# paper_path = './Transform_Model/Model_64x64_GaitGAN_90/PerAngle_embedding_knn_ProbeNM_6001.csv'

# BG
# baseline_path = './Transform_Model/Model_64x64_baselineKNN/PerAngle_knn_ProbeBG_BaselineKNN.csv'
# path_proposed = './Transform_Model/Model_64x64_TripletSAGAN_90_trial3/PerAngle_embedding_knn_ProbeBG_600.csv'
# gaitganTL_path = './Transform_Model/Model_64x64_TripletGAN_90_trial10/PerAngle_generatedata_knn_ProbeBG_6191.csv' 
# paper_path = './Transform_Model/Model_64x64_GaitGAN_90/PerAngle_embedding_knn_ProbeBG_6001.csv'

# CL
baseline_path = './Transform_Model/Model_64x64_baselineKNN/PerAngle_knn_ProbeCL_BaselineKNN.csv'
path_proposed = './Transform_Model/Model_64x64_TripletSAGAN_90_trial3/PerAngle_embedding_knn_ProbeCL_600.csv'
gaitganTL_path = './Transform_Model/Model_64x64_TripletGAN_90_trial10/PerAngle_generatedata_knn_ProbeCL_6191.csv' 
paper_path = './Transform_Model/Model_64x64_GaitGAN_90/PerAngle_embedding_knn_ProbeCL_6001.csv'

# for angle in range(11):
for b, angle in enumerate([3,7]):
    angle_ = angle*18
    df_bs = pd.read_csv(baseline_path, sep=',',header=None)
    df_proposed = pd.read_csv(path_proposed, sep=',',header=None)
    df_gaitganTL = pd.read_csv(gaitganTL_path, sep=',',header=None)
    df_paper = pd.read_csv(paper_path, sep=',',header=None)
    del df_proposed[angle]
    del df_bs[angle]
    del df_gaitganTL[angle]
    del df_paper[angle]

    #2
    l = [i for i in range(11) if i != angle]

    # arr = np.array(total_probe_muAcc)
    fig1 = plt.figure(1,figsize=(20, 6)) #25 6 for 3 angles
    ax1 = fig1.add_subplot(1,2,b+1) # 创建一个Figure                                                          
#     ax1 = fig1.add_subplot(1,1,1)                                  # add_subplot()创建一个子图或多个子图                                            
    ax1.plot((df_bs.iloc[angle][:10])*100, 'o-', color = 'black', label = 'GEI-PCA')       # label设置标签,'o-'代表线型                                                           
    ax1.plot((df_paper.iloc[angle][:10])*100, '>-', color = 'red', label = 'GaitGAN') 
    ax1.plot((df_gaitganTL.iloc[angle][:10])*100, '*-', color = 'blue', label ='GaitGAN+TripletLoss') 
    ax1.plot((df_proposed.iloc[angle][:10])*100, '*-', color = 'green', label = 'Proposed') 
    ax1.set_xlabel('Gallery Angle',fontsize = 15)                              # 设置x轴的标签, fontsize设置字体大小                                             
    ax1.set_ylabel('Accuracy (%)', fontsize = 15)  
    # ax1.set_ylim([0,100])
    ax1.set_xticks(l) 
    ax1.set_xticklabels((df_bs.columns[:-1])*18)
    ax1.set_yticks(range(0,101,10)) 
    ax1.set_title('Probe CL angle at $'+str(angle_)+'^\circ$', fontsize = 18)
    ax1.grid(True, which='major', axis='y')                      # 设置网格                                                               
    ax1.legend(loc = 1, numpoints = 1)  
plt.subplots_adjust(wspace=0.1, hspace=0)
plt.savefig('./Milestone/probecl_crossview/crossview_cl2angles.png')
plt.savefig('./Milestone/probecl_crossview/crossview_cl2angles.eps', format='eps')# 图例, loc='best',即图例放在最不碍事的位置,numpoint图例上自由一个点                       
plt.show()
plt.close()

# %%
#2
l = [i for i in range(11) if i != angle]

# arr = np.array(total_probe_muAcc)
fig1 = plt.figure(1,figsize=(8, 6))                                           # 创建一个Figure                                                          
ax1 = fig1.add_subplot(1,1,1)                                  # add_subplot()创建一个子图或多个子图                                            
ax1.plot((df_bs.iloc[angle][:10])*100, 'o-', color = 'black', label = 'GEI')       # label设置标签,'o-'代表线型                                                           
ax1.plot((df_paper.iloc[angle][:10])*100, '>-', color = 'red', label = 'GaitGAN') 
ax1.plot((df_file2.iloc[angle][:10])*100, '*-', color = 'blue', label = 'GaitGAN+TL') 
ax1.plot((df_file1.iloc[angle][:10])*100, '*-', color = 'green', label = 'Proposed') 
ax1.set_xlabel('Gallery Angle',fontsize = 15)                              # 设置x轴的标签, fontsize设置字体大小                                             
ax1.set_ylabel('Accuracy (%)', fontsize = 15)  
# ax1.set_ylim([0,100])
ax1.set_xticks(l) 
ax1.set_xticklabels((df_bs.columns[:-1])*18)
ax1.set_yticks(range(0,101,10)) 
ax1.set_title('Probe NM angle at $'+str(angle_)+'^\circ$', fontsize = 18)
ax1.grid(True, which='major', axis='y')                      # 设置网格                                                               
ax1.legend(loc = 1, numpoints = 1)    
plt.savefig('./Milestone/crossview'+str(angle_)+'_total.png')# 图例, loc='best',即图例放在最不碍事的位置,numpoint图例上自由一个点                       
plt.show()
plt.close()

# %% [markdown]
# # plot nm, bg, cl accuracy of 11 probe angles in a picture

# %%
import pandas as pd 
from matplotlib import pyplot as plt
# #NM
# baseline_path = './Transform_Model/Model_64x64_baselineKNN/PerAngle_knn_ProbeNM_BaselineKNN_1.csv'
path_proposed_nm = './Transform_Model/Model_64x64_TripletSAGAN_90_trial3/PerAngle_embedding_knn_ProbeNM_600.csv'
# gaitganTL_path = './Transform_Model/Model_64x64_TripletGAN_90_trial10/PerAngle_generatedata_knn_ProbeNM_6191.csv' 
# paper_path = './Transform_Model/Model_64x64_GaitGAN_90/PerAngle_generatedata_knn_ProbeNM_600.csv'

# #BG
# baseline_path = './Transform_Model/Model_64x64_baselineKNN/PerAngle_knn_ProbeBG_BaselineKNN.csv'
path_proposed_bg = './Transform_Model/Model_64x64_TripletSAGAN_90_trial3/PerAngle_embedding_knn_ProbeBG_600.csv'
# gaitganTL_path = './Transform_Model/Model_64x64_TripletGAN_90_trial10/PerAngle_generatedata_knn_ProbeBG_6191.csv' 
# paper_path = './Transform_Model/Model_64x64_GaitGAN_90/PerAngle_embedding_knn_ProbeBG_6001.csv'

# #CL
# baseline_path = './Transform_Model/Model_64x64_baselineKNN/PerAngle_knn_ProbeCL_BaselineKNN.csv'
path_proposed_cl = './Transform_Model/Model_64x64_TripletSAGAN_90_trial3/PerAngle_embedding_knn_ProbeCL_600.csv'
# gaitganTL_path = './Transform_Model/Model_64x64_TripletGAN_90_trial10/ PerAngle_generatedata_knn_ProbeCL_6191.csv' 
# paper_path = './Transform_Model/Model_64x64_GaitGAN_90/PerAngle_embedding_knn_ProbeCL_6001.csv'

for b, angle in enumerate(range(11)):
    angle_ = angle*18
    df_nm = pd.read_csv(path_proposed_nm, sep=',',header=None)
    df_bg = pd.read_csv(path_proposed_bg, sep=',',header=None)
    df_cl = pd.read_csv(path_proposed_cl, sep=',',header=None)

    # arr = np.array(total_probe_muAcc)
    fig1 = plt.figure(1,figsize=(30, 20))                                           # 创建一个Figure                                                          
    ax1 = fig1.add_subplot(3,4,b+1)                                  # add_subplot()创建一个子图或多个子图                                            
    ax1.plot((df_nm[angle][:11])*100, 'o-', color = 'black', label = 'nm')       # label设置标签,'o-'代表线型                                                           
    ax1.plot((df_bg[angle][:11])*100, '>-', color = 'red', label = 'bg') 
    ax1.plot((df_cl[angle][:11])*100, '*-', color = 'blue', label = 'cl') 
    ax1.set_xlabel('Gallery Angle',fontsize = 15)                              # 设置x轴的标签, fontsize设置字体大小                                             
    ax1.set_ylabel('Accuracy (%)', fontsize = 15)  
    # ax1.set_ylim([0,100])
    ax1.set_xticks(range(11)) 
    ax1.set_xticklabels(range(0,181,18))
    ax1.set_yticks(range(0,101,10)) 
    ax1.set_title('Probeset angle at $'+str(angle_)+'^\circ$', fontsize = 18)
    ax1.grid(True, which='major', axis='y')                      # 设置网格                                                               
    ax1.legend(loc = 1, numpoints = 1)    
plt.savefig('./Milestone/acc_probeset.png')# 图例, loc='best',即图例放在最不碍事的位置,numpoint图例上自由一个点                       
plt.show()
plt.close()

# %%
#1

# arr = np.array(total_probe_muAcc)
fig1 = plt.figure(1,figsize=(8, 6))                                           # 创建一个Figure                                                          
ax1 = fig1.add_subplot(1,1,1)                                  # add_subplot()创建一个子图或多个子图                                            
ax1.plot((df_bs[:11][11])*100, 'o-', color = 'blue', label = 'GEI')       # label设置标签,'o-'代表线型                                                           
ax1.plot((df_paper[:11][11])*100, '>-', color = 'red', label = 'GaitGAN') 
ax1.plot((df_file2[:11][11])*100, '*-', color = 'yellow', label = 'Proposed') 
ax1.plot((df_file1[:11][11])*100, '*-', color = 'green', label = 'Proposed+SA') 
ax1.set_xlabel('Probe Angles',fontsize = 15)                              # 设置x轴的标签, fontsize设置字体大小                                             
ax1.set_ylabel('Accuracy (%)', fontsize = 15)  
# ax1.set_ylim([0,100])
ax1.set_xticks(range(11)) 
ax1.set_xticklabels(range(0,181,18))
ax1.set_yticks(range(0,101,10)) 
ax1.set_title('Avarage accuracy in cross view domain', fontsize = 18)
ax1.grid(True, which='major', axis='y')                      # 设置网格                                                               
ax1.legend(loc = 1, numpoints = 1)    
plt.savefig('./Milestone/Avg_crossview_total.png')# 图例, loc='best',即图例放在最不碍事的位置,numpoint图例上自由一个点                       
plt.show()
plt.close()

# %% [markdown]
# # human distribution(2 pics)

# %%
# %load_ext autoreload
# %autoreload 2
from sklearn.neighbors import KNeighborsClassifier
import cv2
import os
import numpy as np
import torch as th
from matplotlib import pyplot as plt
from sklearn.manifold import TSNE
# %matplotlib inline 


# checkpoint = './Transform_Model/Model_64x64_GaitGAN_90/snapshotModel_64x64_GaitGAN_90_600.t7'
# checkpoint = './Transform_Model/Model_64x64_TripletSAGAN_90_trial3/snapshotModel_64x64_TripletSAGAN_90_trial3_600.t7'
Data_Dir = '../GaitRecognition/GEI_CASIA_B/gei/'
    
    
angles_gallery = {'000':"0", '018':"", '036':"36", '054':"", '072':"72",
                  '090':"", '108':"", '126':"", '144':"", '162':"", '180':""}
angles_probe = angles_gallery
X = []
y = []
angle_y = []
pid = 78
for idx, ang in enumerate(angles_gallery):
    #看要不要改成gallery角度是只有90度，比較符合情境，
    for cond in ['nm-01', 'nm-02','nm-03']:#, 'nm-04']:#,'nm-05', 'nm-06']:
        for p in range(pid, 86):                
            #setting1
            path = Data_Dir+'/%03d/%s/%03d-%s-%s.png' % (p, cond, p, cond, ang)
            if not os.path.exists(path):
                continue
#             path = './Transform_64x64_allseq/%03d-%s-%s.png' % (p, cond, ang)
#             if not os.path.exists(path):
#                 continue
            img = cv2.imread(path, 0)    
            img = cv2.resize(img, (64, 64))
            img = img.flatten().astype(np.float32)
            X.append(img)
            y.append(p-pid)
            angle_y.append(angles_gallery[ang])
                 



# checkpoint = './Transform_Model/Model_64x64_GaitGAN_90/snapshotModel_64x64_GaitGAN_90_600.t7'
# checkpoint = './Transform_Model/Model_64x64_TripletSAGAN_90_trial3/snapshotModel_64x64_TripletSAGAN_90_trial3_600.t7'
Data_Dir = '../GaitRecognition/GEI_CASIA_B/gei/'
# st = {0:"dataset", 1:"GaitGAN", 2:"proposed"}
st = {0:"GEI-PCA", 1:"proposed"}
for b in range(2):
    
    angles_gallery = {'000':"0", '018':"", '036':"36", '054':"", '072':"72",
                      '090':"", '108':"", '126':"", '144':"", '162':"", '180':""}
    angles_probe = angles_gallery
    X = []
    y = []
    angle_y = []
    pid = 78
    for idx, ang in enumerate(angles_gallery):
        #看要不要改成gallery角度是只有90度，比較符合情境，
        for cond in ['nm-01', 'nm-02','nm-03']:#, 'nm-04']:#,'nm-05', 'nm-06']:
            for p in range(pid, 86):                
                #setting1
                if(b==0):
                    path = Data_Dir+'/%03d/%s/%03d-%s-%s.png' % (p, cond, p, cond, ang)
                    if not os.path.exists(path):
                        continue
                elif(b==1):  
                    path = './Transform_64x64_proposed/%03d-%s-%s.png' % (p, cond, ang)
                    if not os.path.exists(path):
                        continue
                elif(b==2):  
                    path = './Transform_64x64_gaitgan/%03d-%s-%s.png' % (p, cond, ang)
                    if not os.path.exists(path):
                        continue
                img = cv2.imread(path, 0)    
                img = cv2.resize(img, (64, 64))
                img = img.flatten().astype(np.float32)
                X.append(img)
                y.append(p-pid)
                angle_y.append(angles_gallery[ang])
                
    fig1 = plt.figure(1,figsize=(18, 8)) #25 6 for 1x3
    ax1 = fig1.add_subplot(1,2,b+1) # 创建一个Figure 
    
    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=3000)
    X_embedded = tsne.fit_transform(X)
    color = ['#4682B4', '#0000FF','#D2691E','#000000','#00FFFF','#DB7093',	'#BDB76B',
             '#FF0000','#FF1493','#FF7F50','#FFD700','#800080','#006400','#20B2AA']
    # 淡藍色 藍色 暗橘色 黑色 亮青藍色 粉紅色 紅色 紫紅色 淡橘色 黃色 紫色 綠色 暗青藍色 
    x_min, x_max = np.min(X_embedded, 0), np.max(X_embedded, 0)
    X_embedded = (X_embedded - x_min) / (x_max - x_min)

                 
    for i in range(X_embedded.shape[0]):
        # plot colored number
        ax1.text(X_embedded[i, 0], X_embedded[i, 1], angle_y[i],
                 color = color[y[i]],
                 fontdict={'weight': 'bold', 'size': 13})
    ax1.set_title("$ID_{78}$~$ID_{85}$ of human distribution from "+st[b], fontsize = 18)

# plt.title("$S_{78}$~$S_{85}$ of human distribution from dataset", fontsize = 18)
plt.subplots_adjust(wspace=0.1, hspace=0)
plt.savefig('./Milestone/78_85_Distribution_2x1.png')
plt.savefig('./Milestone/78_85_Distribution_2x1.eps', format='eps')
plt.show()

# %% [markdown]
# ## human distribution(1 pics)

# %%
# %load_ext autoreload
# %autoreload 2
from sklearn.neighbors import KNeighborsClassifier
import cv2
import os
import numpy as np
import torch as th
from matplotlib import pyplot as plt
from sklearn.manifold import TSNE
# %matplotlib inline 


# checkpoint = './Transform_Model/Model_64x64_GaitGAN_90/snapshotModel_64x64_GaitGAN_90_600.t7'
# checkpoint = './Transform_Model/Model_64x64_TripletSAGAN_90_trial3/snapshotModel_64x64_TripletSAGAN_90_trial3_600.t7'
Data_Dir = '../GaitRecognition/GEI_CASIA_B/gei/'
    
    
angles_gallery = {'000':"0", '018':"", '036':"36", '054':"", '072':"72",
                  '090':"", '108':"", '126':"", '144':"", '162':"", '180':""}
angles_probe = angles_gallery
X = []
y = []
angle_y = []
pid = 78
for idx, ang in enumerate(angles_gallery):
    #看要不要改成gallery角度是只有90度，比較符合情境，
    for cond in ['nm-01', 'nm-02','nm-03']:#, 'nm-04']:#,'nm-05', 'nm-06']:
        for p in range(pid, 86):                
            #setting1
            path = Data_Dir+'/%03d/%s/%03d-%s-%s.png' % (p, cond, p, cond, ang)
            if not os.path.exists(path):
                continue
#             path = './Transform_64x64_allseq/%03d-%s-%s.png' % (p, cond, ang)
#             if not os.path.exists(path):
#                 continue
            img = cv2.imread(path, 0)    
            img = cv2.resize(img, (64, 64))
            img = img.flatten().astype(np.float32)
            X.append(img)
            y.append(p-pid)
            angle_y.append(angles_gallery[ang])
            
            
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=3000)
X_embedded = tsne.fit_transform(X)
color = ['#4682B4', '#0000FF','#D2691E','#000000','#00FFFF','#DB7093',	'#BDB76B',
         '#FF0000','#FF1493','#FF7F50','#FFD700','#800080','#006400','#20B2AA']
# 淡藍色 藍色 暗橘色 黑色 亮青藍色 粉紅色 紅色 紫紅色 淡橘色 黃色 紫色 綠色 暗青藍色 
x_min, x_max = np.min(X_embedded, 0), np.max(X_embedded, 0)
X_embedded = (X_embedded - x_min) / (x_max - x_min)
# Plot colors numbers
plt.figure(figsize=(8,8))
ax = plt.subplot(111)
num_y = len(set(y))

print(X_embedded.shape)
print(len(y))
print(len(angle_y))
for i in range(X_embedded.shape[0]):
    # plot colored number
    plt.text(X_embedded[i, 0], X_embedded[i, 1], angle_y[i],
#                  color = plt.get_cmap(color_list[d[i]]),
#                  color=plt.cm.Set1(y[i]),
#                  color=plt.cm.bwr(y[i]*100./20),
             color = color[y[i]],
             fontdict={'weight': 'bold', 'size': 13})

# plt.xticks([]), plt.yticks([])
# plt.legend(map(str,(range(62,67))))

plt.title("$S_{78}$~$S_{85}$ of human distribution from dataset", fontsize = 18)
plt.savefig('./Milestone/78_85_Distribution.png')
plt.savefig('./Milestone/78_85_Distribution.eps', format='eps')
plt.show()
# Out:
# (264, 2)
# 264
# 264
